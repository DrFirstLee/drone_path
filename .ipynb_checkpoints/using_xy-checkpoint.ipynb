# %%
# !pip --version
# Out:
# pip 25.2 from C:\Users\DrFirst\AppData\Local\anaconda3\Lib\site-packages\pip (python 3.12)

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\DrFirst\AppData\Local\anaconda3\python.exe

# %%
import os
import numpy as np
import pandas as pd
import folium
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from hmmlearn import hmm

target_file = r"C:\Users\DrFirst\Desktop\drone\포항긴거_20250704_020715.csv"

# 1. 데이터 로드 (오직 X, Y만 추출)
df = pd.read_csv(target_file, header=None)

valid_start_idx = -1
check_limit = min(df.shape[1], 5)

# 타임스탬프 위치 찾기
for i in range(check_limit):
    try:
        if float(df.iloc[0, i]) > 500000:
            valid_start_idx = i
            break
    except:
        continue

# 타임스탬프 다음 2개 컬럼을 Longitude(X), Latitude(Y)로 강제 할당
if valid_start_idx != -1 and df.shape[1] >= valid_start_idx + 3:
    df = df.iloc[:, [valid_start_idx+1, valid_start_idx+2]]
else:
    # 못 찾으면 첫 2개 컬럼을 사용
    df = df.iloc[:, [0, 1]]

df.columns = ['Longitude', 'Latitude']

# 결측치 및 문자열 처리
df['Latitude'] = pd.to_numeric(df['Latitude'], errors='coerce')
df['Longitude'] = pd.to_numeric(df['Longitude'], errors='coerce')
df = df.dropna().reset_index(drop=True)

# 2. X, Y 좌표만으로 비행 물리량(Feature) 수학적 도출
R = 6371000.0 # 지구 반지름(m)
lat_rad = np.deg2rad(df['Latitude'])
lon_rad = np.deg2rad(df['Longitude'])

# X, Y 변화량 (미터 단위)
dx = R * lon_rad.diff().fillna(0) * np.cos(lat_rad.mean())
dy = R * lat_rad.diff().fillna(0)

# 진행 방향(가상 Yaw) 계산 (아크탄젠트 사용)
heading_rad = np.arctan2(dy, dx)
df['Pseudo_Yaw'] = np.rad2deg(heading_rad)
df['Pseudo_Yaw'] = df['Pseudo_Yaw'].bfill()

# 각도 튀는 현상(360 -> 0) 보정
yaw_rad_unwrapped = np.unwrap(np.deg2rad(df['Pseudo_Yaw']))
df['Yaw_unwrap'] = np.rad2deg(yaw_rad_unwrapped)

window_size = 30
df['Yaw_diff'] = df['Yaw_unwrap'].diff().fillna(0).abs()
df['Yaw_rate'] = df['Yaw_diff'].rolling(window=window_size, center=True).mean().fillna(0)
df['Yaw_std'] = df['Yaw_unwrap'].rolling(window=window_size, center=True).std().fillna(0)

# 이동 속도 및 원심 가속도 추정
ds = np.sqrt(dx**2 + dy**2)
df['Speed_proxy'] = ds.rolling(window=window_size, center=True).mean().fillna(0)
df['Centripetal_Acc'] = df['Speed_proxy'] * df['Yaw_rate']

feature_cols = ['Yaw_rate', 'Yaw_std', 'Centripetal_Acc']
df[feature_cols] = df[feature_cols].fillna(0)

# 3. HMM Clustering
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df[feature_cols])

model = hmm.GaussianHMM(n_components=2, covariance_type="diag", n_iter=100, random_state=42)
model.fit(X_scaled)
df['State_Raw'] = model.predict(X_scaled)

# 어느 쪽이 '회전(Turn)'인지 자동 식별
state_yaw_rates = []
for s in range(2):
    state_mean = np.mean(X_scaled[df['State_Raw'] == s], axis=0)
    state_yaw_rates.append(state_mean[feature_cols.index('Yaw_rate')])
turn_label = np.argmax(state_yaw_rates)

df['State'] = df['State_Raw'].apply(lambda x: 1 if x == turn_label else 0)
df['State_Smooth'] = df['State']

df['Segment_Change'] = df['State_Smooth'].diff().fillna(0).abs()
df['Final_Segment_ID'] = df['Segment_Change'].cumsum().astype(int)

# 4. PCA 기반 직선성 정밀 검증
def is_linear_path(lats, lons, linearity_threshold=0.98):
    if len(lats) < 6:
        return False, 0.0
    lat_rad = np.deg2rad(np.mean(lats))
    xs = np.deg2rad(lons) * R * np.cos(lat_rad)
    ys = np.deg2rad(lats) * R
    coords = np.column_stack([xs, ys])
    
    span = np.ptp(coords, axis=0)
    if np.max(span) < 1.0:
        return True, 1.0
        
    pca = PCA(n_components=2)
    pca.fit(coords)
    ratio = pca.explained_variance_ratio_[0]
    return ratio >= linearity_threshold, ratio

df['State_Final'] = df['State_Smooth'].copy()
df['PCA_Ratio'] = 0.0

rotate_seg_ids = df[df['State_Smooth'] == 1]['Final_Segment_ID'].unique()
for rid in rotate_seg_ids:
    seg_mask = (df['Final_Segment_ID'] == rid)
    seg = df[seg_mask]
    lats = seg['Latitude'].values
    lons = seg['Longitude'].values

    gps_is_linear, pca_ratio = is_linear_path(lats, lons)
    df.loc[seg_mask, 'PCA_Ratio'] = pca_ratio

    yaw_change = seg['Yaw_unwrap'].max() - seg['Yaw_unwrap'].min() if len(seg) > 0 else 0.0
    YAW_CHANGE_THRESHOLD = 45.0
    
    if gps_is_linear and yaw_change < YAW_CHANGE_THRESHOLD:
        df.loc[seg_mask, 'State_Final'] = 3
    else:
        df.loc[seg_mask, 'State_Final'] = 2 if gps_is_linear else 1

df.loc[df['State_Smooth'] == 0, 'State_Final'] = 0
df['Segment_Change_Final'] = (df['State_Final'] != df['State_Final'].shift(1)).astype(int)
df['Final_Segment_ID'] = df['Segment_Change_Final'].cumsum().astype(int)

# 5. 체인 병합 알고리즘 (Chain Merging)
seg_order_df = df.groupby('Final_Segment_ID').agg(
    state_final=('State_Final', 'first'),
    first_idx=('Final_Segment_ID', lambda x: x.index.min())
).reset_index().sort_values('first_idx')

ordered_segs = list(zip(seg_order_df['Final_Segment_ID'].tolist(), seg_order_df['state_final'].tolist()))

runs = []
current_run = []
for seg_id, state in ordered_segs:
    if state in (0, 2, 3):
        current_run.append((seg_id, state))
    else:
        if current_run:
            runs.append(current_run)
            current_run = []
        runs.append([(seg_id, state)])
if current_run:
    runs.append(current_run)

merge_ops = {}
for run in runs:
    if len(run) == 1 and run[0][1] == 1:
        continue
    line_positions = [i for i, (_, st) in enumerate(run) if st == 0]
    if not line_positions:
        continue
    target_id = run[line_positions[0]][0]
    for old_id, _ in run:
        if old_id != target_id:
            merge_ops[old_id] = target_id

for old_id, new_id in merge_ops.items():
    df.loc[df['Final_Segment_ID'] == old_id, 'Final_Segment_ID'] = new_id

all_target_ids = set(merge_ops.values())
for tid in all_target_ids:
    df.loc[(df['Final_Segment_ID'] == tid) & (df['State_Final'].isin([2, 3])), 'State_Final'] = 0

alive_seg_ids = sorted(df['Final_Segment_ID'].unique())
id_mapping = {old_id: new_idx for new_idx, old_id in enumerate(alive_seg_ids, start=1)}
df['Final_Segment_ID'] = df['Final_Segment_ID'].map(id_mapping).astype(int)

# 6. Folium 지도 시각화
center_lat, center_lon = df['Latitude'].mean(), df['Longitude'].mean()
m = folium.Map(location=[center_lat, center_lon], zoom_start=16)

all_coords = df[['Latitude', 'Longitude']].values.tolist()
folium.PolyLine(locations=all_coords, color="#000000", weight=5, opacity=0.5).add_to(m)

colors = [
    '#FF0000', '#00FF00', '#0000FF', '#FFFF00', '#FF00FF', '#00FFFF', '#FF8000', '#0080FF', 
    '#FF0080', '#80FF00', '#00FF80', '#FF4040', '#4040FF', '#FFD700', '#ADFF2F', '#FF69B4', 
    '#1E90FF', '#DC143C'
]

for seg_id in sorted(df['Final_Segment_ID'].unique()):
    group = df[df['Final_Segment_ID'] == seg_id]
    seg_state_final = group['State_Final'].iloc[0]

    if seg_state_final == 0:
        color, weight, opacity, dash_array = colors[seg_id % len(colors)], 3, 0.8, None
    elif seg_state_final == 1:
        color, weight, opacity, dash_array = colors[seg_id % len(colors)], 5, 0.9, '5, 5'
    elif seg_state_final == 2:
        color, weight, opacity, dash_array = '#9400D3', 5, 0.9, '10, 5'
    else:
        color, weight, opacity, dash_array = '#FF6600', 5, 0.9, '10, 5'

    indices = group.index.values
    if len(indices) > 0:
        split_locs = np.where(np.diff(indices) > 1)[0] + 1
        for sub_indices in np.split(indices, split_locs):
            if len(sub_indices) < 2: continue
            sub_coords = df.loc[sub_indices, ['Latitude', 'Longitude']].values.tolist()
            folium.PolyLine(
                locations=sub_coords, color=color, weight=weight, 
                opacity=opacity, dash_array=dash_array
            ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_55b5f46ddf9f0b937a41a6f49577efc3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_55b5f46ddf9f0b937a41a6f49577efc3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_55b5f46ddf9f0b937a41a6f49577efc3 = L.map(
#                 &quot;map_55b5f46ddf9f0b937a41a6f49577efc3&quot;,
#                 {
#                     center: [36.13617153110266, 129.4092742498913],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0995befe9787e86ca46e44d80bc528d7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0995befe9787e86ca46e44d80bc528d7.addTo(map_55b5f46ddf9f0b937a41a6f49577efc3);
#
#
#             var poly_line_433d3f31a0366f04ae9c108304aa096b = L.polyline(
#                 [[36.14086634, 129.3948083], [36.14086629, 129.3948082], [36.14086625, 129.394808], [36.14086625, 129.394808], [36.14086615, 129.3948079], [36.14086615, 129.3948079], [36.14086608, 129.3948078], [36.14086604, 129.3948078], [36.14086596, 129.3948077], [36.14086585, 129.3948076], [36.1408657, 129.3948075], [36.14086559, 129.3948073], [36.1408655, 129.3948072], [36.14086544, 129.3948072], [36.14086539, 129.3948071], [36.14086539, 129.3948071], [36.14086528, 129.3948072], [36.14086517, 129.3948071], [36.14086503, 129.394807], [36.14086493, 129.3948068], [36.14086481, 129.3948068], [36.14086467, 129.3948067], [36.14086453, 129.3948067], [36.1408643, 129.3948067], [36.1408641, 129.3948067], [36.1408641, 129.3948067], [36.14086399, 129.3948066], [36.1408639, 129.3948066], [36.1408639, 129.3948066], [36.14086391, 129.3948066], [36.14086388, 129.3948066], [36.14086384, 129.3948067], [36.14086382, 129.3948068], [36.14086379, 129.3948068], [36.14086375, 129.3948069], [36.14086375, 129.3948069], [36.14086371, 129.3948069], [36.14086367, 129.394807], [36.1408637, 129.394807], [36.14086372, 129.394807], [36.14086376, 129.3948071], [36.14086382, 129.3948072], [36.14086385, 129.3948072], [36.14086388, 129.3948073], [36.1408639, 129.3948073], [36.1408639, 129.3948073], [36.140864, 129.3948071], [36.14086402, 129.394807], [36.14086399, 129.3948071], [36.14086397, 129.3948071], [36.14086397, 129.3948071], [36.14086398, 129.3948071], [36.14086398, 129.3948071], [36.14086395, 129.3948073], [36.14086396, 129.3948073], [36.14086396, 129.3948073], [36.14086403, 129.3948073], [36.14086409, 129.3948073], [36.1408642, 129.3948072], [36.14086421, 129.3948072], [36.1408642, 129.3948072], [36.14086417, 129.3948072], [36.14086407, 129.3948072], [36.14086401, 129.3948072], [36.14086398, 129.3948072], [36.14086398, 129.3948072], [36.14086396, 129.3948072], [36.14086396, 129.3948071], [36.14086397, 129.3948071], [36.140864, 129.3948071], [36.14086411, 129.3948071], [36.14086414, 129.3948071], [36.1408642, 129.3948071], [36.14086422, 129.3948071], [36.14086426, 129.3948071], [36.14086426, 129.3948071], [36.14086426, 129.3948071], [36.14086427, 129.3948071], [36.14086432, 129.3948071], [36.14086445, 129.3948072], [36.14086451, 129.3948072], [36.1408645, 129.3948072], [36.14086449, 129.3948073], [36.14086448, 129.3948073], [36.14086449, 129.3948073], [36.14086449, 129.3948073], [36.14086447, 129.3948073], [36.14086445, 129.3948072], [36.14086439, 129.3948072], [36.1408644, 129.3948071], [36.14086442, 129.394807], [36.14086445, 129.394807], [36.14086449, 129.394807], [36.14086451, 129.394807], [36.14086452, 129.394807], [36.14086452, 129.394807], [36.14086456, 129.394807], [36.14086463, 129.3948071], [36.14086466, 129.3948071], [36.14086465, 129.3948072], [36.14086456, 129.3948073], [36.14086454, 129.3948074], [36.14086453, 129.3948074], [36.14086453, 129.3948075], [36.14086454, 129.3948075], [36.14086454, 129.3948075], [36.14086448, 129.3948077], [36.14086444, 129.3948077], [36.14086443, 129.3948078], [36.1408644, 129.3948079], [36.14086437, 129.3948079], [36.14086438, 129.394808], [36.1408644, 129.3948081], [36.14086447, 129.3948081], [36.14086448, 129.3948082], [36.14086448, 129.3948082], [36.14086437, 129.3948083], [36.14086419, 129.3948083], [36.14086416, 129.3948083], [36.14086414, 129.3948083], [36.14086404, 129.3948083], [36.14086397, 129.3948083], [36.14086396, 129.3948082], [36.140864, 129.3948081], [36.14086412, 129.394808], [36.14086412, 129.394808], [36.14086417, 129.394808], [36.14086416, 129.394808], [36.14086429, 129.3948079], [36.14086435, 129.3948078], [36.14086441, 129.3948078], [36.14086448, 129.3948079], [36.14086459, 129.3948079], [36.1408646, 129.394808], [36.14086478, 129.3948083], [36.14086478, 129.3948083], [36.1408

# %%
import os
import numpy as np
import pandas as pd
import folium
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from hmmlearn import hmm

target_file = r"C:\Users\DrFirst\Desktop\drone\포항긴거_20250704_020715.csv"

column_names = [
    'Time', 'Longitude', 'Latitude', 'Altitude', 
    'Roll', 'Pitch', 'Yaw', 
    'Mag1_X', 'Mag1_Y', 'Mag1_Z', 
    'Mag2_X', 'Mag2_Y', 'Mag2_Z'
]

df = pd.read_csv(target_file, header=None)

valid_start_idx = -1
check_limit = min(df.shape[1], 5)

for i in range(check_limit):
    try:
        sample_val = float(df.iloc[0, i])
        if sample_val > 500000:
            valid_start_idx = i
            break
    except:
        continue

if valid_start_idx != -1:
    end_idx = valid_start_idx + len(column_names)
    if df.shape[1] >= end_idx:
        df = df.iloc[:, valid_start_idx:end_idx]
        df.columns = column_names
    else:
        df = df.iloc[:, valid_start_idx:]
        df.columns = column_names[:df.shape[1]]
else:
    df.columns = column_names[:df.shape[1]]

df['Latitude'] = pd.to_numeric(df['Latitude'], errors='coerce')
df['Longitude'] = pd.to_numeric(df['Longitude'], errors='coerce')
df = df.dropna(subset=['Latitude', 'Longitude']).reset_index(drop=True)

R = 6371000.0
lat_rad = np.deg2rad(df['Latitude'])
lon_rad = np.deg2rad(df['Longitude'])

dx = R * lon_rad.diff().fillna(0) * np.cos(lat_rad.mean())
dy = R * lat_rad.diff().fillna(0)

heading_rad = np.arctan2(dy, dx)
df['Pseudo_Yaw'] = np.rad2deg(heading_rad)
df['Pseudo_Yaw'] = df['Pseudo_Yaw'].bfill()

yaw_rad_unwrapped = np.unwrap(np.deg2rad(df['Pseudo_Yaw']))
df['Yaw_unwrap'] = np.rad2deg(yaw_rad_unwrapped)

window_size = 30
df['Yaw_diff'] = df['Yaw_unwrap'].diff().fillna(0).abs()
df['Yaw_rate'] = df['Yaw_diff'].rolling(window=window_size, center=True).mean().fillna(0)
df['Yaw_std'] = df['Yaw_unwrap'].rolling(window=window_size, center=True).std().fillna(0)

ds = np.sqrt(dx**2 + dy**2)
df['Speed_proxy'] = ds.rolling(window=window_size, center=True).mean().fillna(0)
df['Centripetal_Acc'] = df['Speed_proxy'] * df['Yaw_rate']

feature_cols = ['Yaw_rate', 'Yaw_std', 'Centripetal_Acc']
df[feature_cols] = df[feature_cols].fillna(0)

scaler = StandardScaler()
X_scaled = scaler.fit_transform(df[feature_cols])

model = hmm.GaussianHMM(n_components=2, covariance_type="diag", n_iter=100, random_state=42)
model.fit(X_scaled)
df['State_Raw'] = model.predict(X_scaled)

state_yaw_rates = []
for s in range(2):
    state_mean = np.mean(X_scaled[df['State_Raw'] == s], axis=0)
    state_yaw_rates.append(state_mean[feature_cols.index('Yaw_rate')])
turn_label = np.argmax(state_yaw_rates)

df['State'] = df['State_Raw'].apply(lambda x: 1 if x == turn_label else 0)
df['State_Smooth'] = df['State']

df['Segment_Change'] = df['State_Smooth'].diff().fillna(0).abs()
df['Final_Segment_ID'] = df['Segment_Change'].cumsum().astype(int)

def is_linear_path(lats, lons, linearity_threshold=0.98):
    if len(lats) < 6:
        return False, 0.0
    R = 6371000.0
    lat_rad = np.deg2rad(np.mean(lats))
    xs = np.deg2rad(lons) * R * np.cos(lat_rad)
    ys = np.deg2rad(lats) * R
    coords = np.column_stack([xs, ys])
    
    span = np.ptp(coords, axis=0)
    if np.max(span) < 1.0:
        return True, 1.0
        
    pca = PCA(n_components=2)
    pca.fit(coords)
    ratio = pca.explained_variance_ratio_[0]
    return ratio >= linearity_threshold, ratio

df['State_Final'] = df['State_Smooth'].copy()
df['PCA_Ratio'] = 0.0

rotate_seg_ids = df[df['State_Smooth'] == 1]['Final_Segment_ID'].unique()
for rid in rotate_seg_ids:
    seg_mask = (df['Final_Segment_ID'] == rid)
    seg = df[seg_mask]
    lats = seg['Latitude'].values
    lons = seg['Longitude'].values

    gps_is_linear, pca_ratio = is_linear_path(lats, lons)
    df.loc[seg_mask, 'PCA_Ratio'] = pca_ratio

    if len(seg) > 0:
        yaw_change = seg['Yaw_unwrap'].max() - seg['Yaw_unwrap'].min()
    else:
        yaw_change = 0.0

    YAW_CHANGE_THRESHOLD = 45.0
    
    if gps_is_linear and yaw_change < YAW_CHANGE_THRESHOLD:
        df.loc[seg_mask, 'State_Final'] = 3
    else:
        if gps_is_linear:
            df.loc[seg_mask, 'State_Final'] = 2
        else:
            df.loc[seg_mask, 'State_Final'] = 1

df.loc[df['State_Smooth'] == 0, 'State_Final'] = 0
df['Segment_Change_Final'] = (df['State_Final'] != df['State_Final'].shift(1)).astype(int)
df['Final_Segment_ID'] = df['Segment_Change_Final'].cumsum().astype(int)

seg_order_df = df.groupby('Final_Segment_ID').agg(
    state_final=('State_Final', 'first'),
    first_idx=('Final_Segment_ID', lambda x: x.index.min())
).reset_index().sort_values('first_idx')

ordered_segs = list(zip(seg_order_df['Final_Segment_ID'].tolist(), seg_order_df['state_final'].tolist()))

runs = []
current_run = []
for seg_id, state in ordered_segs:
    if state in (0, 2, 3):
        current_run.append((seg_id, state))
    else:
        if current_run:
            runs.append(current_run)
            current_run = []
        runs.append([(seg_id, state)])
if current_run:
    runs.append(current_run)

merge_ops = {}
for run in runs:
    if len(run) == 1 and run[0][1] == 1:
        continue
    line_positions = [i for i, (_, st) in enumerate(run) if st == 0]
    if not line_positions:
        continue
    target_id = run[line_positions[0]][0]
    for old_id, _ in run:
        if old_id != target_id:
            merge_ops[old_id] = target_id

for old_id, new_id in merge_ops.items():
    df.loc[df['Final_Segment_ID'] == old_id, 'Final_Segment_ID'] = new_id

all_target_ids = set(merge_ops.values())
for tid in all_target_ids:
    df.loc[(df['Final_Segment_ID'] == tid) & (df['State_Final'].isin([2, 3])), 'State_Final'] = 0

alive_seg_ids = sorted(df['Final_Segment_ID'].unique())
id_mapping = {old_id: new_idx for new_idx, old_id in enumerate(alive_seg_ids, start=1)}
df['Final_Segment_ID'] = df['Final_Segment_ID'].map(id_mapping).astype(int)

center_lat = df['Latitude'].mean()
center_lon = df['Longitude'].mean()
m = folium.Map(location=[center_lat, center_lon], zoom_start=16)

all_coords = df[['Latitude', 'Longitude']].values.tolist()
folium.PolyLine(locations=all_coords, color="#000000", weight=5, opacity=0.5).add_to(m)

colors = [
    '#FF0000', '#00FF00', '#0000FF', '#FFFF00', '#FF00FF', '#00FFFF', '#FF8000', '#0080FF', 
    '#FF0080', '#80FF00', '#00FF80', '#FF4040', '#4040FF', '#FFD700', '#ADFF2F', '#FF69B4', 
    '#1E90FF', '#DC143C'
]

sorted_seg_ids = sorted(df['Final_Segment_ID'].unique())

for seg_id in sorted_seg_ids:
    group = df[df['Final_Segment_ID'] == seg_id]
    seg_state_final = group['State_Final'].iloc[0]

    if seg_state_final == 0:
        color = colors[seg_id % len(colors)]
        weight, opacity, dash_array = 3, 0.8, None
    elif seg_state_final == 1:
        color = colors[seg_id % len(colors)]
        weight, opacity, dash_array = 5, 0.9, '5, 5'
    elif seg_state_final == 2:
        color, weight, opacity, dash_array = '#9400D3', 5, 0.9, '10, 5'
    else:
        color, weight, opacity, dash_array = '#FF6600', 5, 0.9, '10, 5'

    indices = group.index.values
    if len(indices) > 0:
        split_locs = np.where(np.diff(indices) > 1)[0] + 1
        for sub_indices in np.split(indices, split_locs):
            if len(sub_indices) < 2: continue
            sub_coords = df.loc[sub_indices, ['Latitude', 'Longitude']].values.tolist()
            folium.PolyLine(
                locations=sub_coords, color=color, weight=weight, 
                opacity=opacity, dash_array=dash_array
            ).add_to(m)

# 지도 출력
m
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
#     self.io_loop.start()
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\asyncio\windows_events.py", line 322, in run_forever
#     super().run_forever()
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\asyncio\base_events.py", line 641, in run_forever
#     self._run_once()
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\asyncio\base_events.py", line 1987, in _run_once
#     handle._run()
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 523, in process_one
#     await dispatch(*args)
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 429, in dispatch_shell
#     await result
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 429, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\DrFirst\AppData\Local\Temp\ipykernel_12448\1681929752.py", line 3, in <module>
#     import pandas as pd
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\site-packages\pandas\__init__.py", line 26, in <module>
#     from pandas.compat import (
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\site-packages\pandas\compat\__init__.py", line 27, in <module>
#     from pandas.compat.pyarrow import (
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\site-packages\pandas\compat\pyarrow.py", line 8, in <module>
#     import pyarrow as pa
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\site-packages\pyarrow\__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\numpy\core\_multiarray_umath.py:46, in __getattr__(attr_name)
#      41     # Also print the message (with traceback).  This is because old versions
#      42     # of NumPy unfortunately set up the import to replace (and hide) the
#      43     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      44     # seem to swallow it and we should be failing anyway...
#      45     sys.stderr.write(msg + tb_msg)
# ---> 46     raise ImportError(msg)
#      48 ret = getattr(_multiarray_umath, attr_name, None)
#      49 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
#     self.io_loop.start()
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\asyncio\windows_events.py", line 322, in run_forever
#     super().run_forever()
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\asyncio\base_events.py", line 641, in run_forever
#     self._run_once()
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\asyncio\base_events.py", line 1987, in _run_once
#     handle._run()
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 523, in process_one
#     await dispatch(*args)
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 429, in dispatch_shell
#     await result
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 429, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\DrFirst\AppData\Local\Temp\ipykernel_12448\1681929752.py", line 3, in <module>
#     import pandas as pd
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\site-packages\pandas\__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\site-packages\pandas\core\api.py", line 1, in <module>
#     from pandas._libs import (
#   File "C:\Users\DrFirst\AppData\Local\anaconda3\Lib\site-packages\pandas\_libs\__init__.py", line 17, in <module>
#     import pandas._libs.pandas_datetime  # noqa: F401 # isort: skip # type: ignore[reportUnusedImport]
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\numpy\core\_multiarray_umath.py:46, in __getattr__(attr_name)
#      41     # Also print the message (with traceback).  This is because old versions
#      42     # of NumPy unfortunately set up the import to replace (and hide) the
#      43     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      44     # seem to swallow it and we should be failing anyway...
#      45     sys.stderr.write(msg + tb_msg)
# ---> 46     raise ImportError(msg)
#      48 ret = getattr(_multiarray_umath, attr_name, None)
#      49 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 import os
#       2 import numpy as np
# ----> 3 import pandas as pd
#       4 import folium
#       5 from sklearn.preprocessing import StandardScaler
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\__init__.py:49
#      46 # let init-time option registration happen
#      47 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 49 from pandas.core.api import (
#      50     # dtype
#      51     ArrowDtype,
#      52     Int8Dtype,
#      53     Int16Dtype,
#      54     Int32Dtype,
#      55     Int64Dtype,
#      56     UInt8Dtype,
#      57     UInt16Dtype,
#      58     UInt32Dtype,
#      59     UInt64Dtype,
#      60     Float32Dtype,
#      61     Float64Dtype,
#      62     CategoricalDtype,
#      63     PeriodDtype,
#      64     IntervalDtype,
#      65     DatetimeTZDtype,
#      66     StringDtype,
#      67     BooleanDtype,
#      68     # missing
#      69     NA,
#      70     isna,
#      71     isnull,
#      72     notna,
#      73     notnull,
#      74     # indexes
#      75     Index,
#      76     CategoricalIndex,
#      77     RangeIndex,
#      78     MultiIndex,
#      79     IntervalIndex,
#      80     TimedeltaIndex,
#      81     DatetimeIndex,
#      82     PeriodIndex,
#      83     IndexSlice,
#      84     # tseries
#      85     NaT,
#      86     Period,
#      87     period_range,
#      88     Timedelta,
#      89     timedelta_range,
#      90     Timestamp,
#      91     date_range,
#      92     bdate_range,
#      93     Interval,
#      94     interval_range,
#      95     DateOffset,
#      96     # conversion
#      97     to_numeric,
#      98     to_datetime,
#      99     to_timedelta,
#     100     # misc
#     101     Flags,
#     102     Grouper,
#     103     factorize,
#     104     unique,
#     105     value_counts,
#     106     NamedAgg,
#     107     array,
#     108     Categorical,
#     109     set_eng_float_format,
#     110     Series,
#     111     DataFrame,
#     112 )
#     114 from pandas.core.dtypes.dtypes import SparseDtype
#     116 from pandas.tseries.api import infer_freq
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\api.py:1
# ----> 1 from pandas._libs import (
#       2     NaT,
#       3     Period,
#       4     Timedelta,
#       5     Timestamp,
#       6 )
#       7 from pandas._libs.missing import NA
#       9 from pandas.core.dtypes.dtypes import (
#      10     ArrowDtype,
#      11     CategoricalDtype,
#    (...)
#      14     PeriodDtype,
#      15 )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\_libs\__init__.py:17
#      13 # Below imports needs to happen first to ensure pandas top level
#      14 # module gets monkeypatched with the pandas_datetime_CAPI
#      15 # see pandas_datetime_exec in pd_datetime.c
#      16 import pandas._libs.pandas_parser  # isort: skip # type: ignore[reportUnusedImport]
# ---> 17 import pandas._libs.pandas_datetime  # noqa: F401 # isort: skip # type: ignore[reportUnusedImport]
#      18 from pandas._libs.interval import Interval
#      19 from pandas._libs.tslibs import (
#      20     NaT,
#      21     NaTType,
#    (...)
#      26     iNaT,
#      27 )
#
# ImportError: numpy.core.multiarray failed to import
